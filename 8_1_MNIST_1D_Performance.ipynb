# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-0xtkyg8u
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-0xtkyg8u
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Dropout(0.2),
    torch.nn.Linear(D_k, D_o)
  );


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
  print("Initializing layer")

model.apply(weights_init)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Dropout(p=0.2, inplace=False)
#   (7): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001,betas=(.09, 0.999),)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.906635, train error 72.35,  test loss 1.981470, test error 76.50
# Epoch     1, train loss 1.732118, train error 66.93,  test loss 1.804001, test error 71.60
# Epoch     2, train loss 1.598526, train error 60.30,  test loss 1.717232, test error 68.50
# Epoch     3, train loss 1.489506, train error 56.47,  test loss 1.657710, test error 64.40
# Epoch     4, train loss 1.398553, train error 51.38,  test loss 1.568139, test error 61.60
# Epoch     5, train loss 1.320898, train error 49.35,  test loss 1.529645, test error 59.50
# Epoch     6, train loss 1.246559, train error 45.78,  test loss 1.434358, test error 55.90
# Epoch     7, train loss 1.180740, train error 43.20,  test loss 1.419689, test error 54.60
# Epoch     8, train loss 1.106194, train error 40.55,  test loss 1.360185, test error 52.90
# Epoch     9, train loss 1.052650, train error 38.38,  test loss 1.347536, test error 52.50
# Epoch    10, train loss 0.993048, train error 35.57,  test loss 1.300755, test error 49.30
# Epoch    11, train loss 0.964586, train error 34.25,  test loss 1.292357, test error 49.90
# Epoch    12, train loss 0.954239, train error 34.05,  test loss 1.262864, test error 48.80
# Epoch    13, train loss 0.922069, train error 33.07,  test loss 1.274891, test error 49.20
# Epoch    14, train loss 0.901233, train error 31.72,  test loss 1.259673, test error 47.70
# Epoch    15, train loss 0.881624, train error 31.03,  test loss 1.235499, test error 48.40
# Epoch    16, train loss 0.843800, train error 30.07,  test loss 1.220549, test error 46.60
# Epoch    17, train loss 0.823241, train error 28.80,  test loss 1.233652, test error 47.70
# Epoch    18, train loss 0.810088, train error 28.22,  test loss 1.228259, test error 45.80
# Epoch    19, train loss 0.785465, train error 26.75,  test loss 1.197582, test error 46.50
# Epoch    20, train loss 0.764416, train error 26.15,  test loss 1.176107, test error 44.00
# Epoch    21, train loss 0.761786, train error 26.88,  test loss 1.224123, test error 45.90
# Epoch    22, train loss 0.744149, train error 26.05,  test loss 1.210284, test error 45.50
# Epoch    23, train loss 0.744825, train error 25.75,  test loss 1.169999, test error 43.20
# Epoch    24, train loss 0.722581, train error 24.75,  test loss 1.160776, test error 43.20
# Epoch    25, train loss 0.722551, train error 24.68,  test loss 1.201674, test error 44.80
# Epoch    26, train loss 0.720205, train error 25.57,  test loss 1.210661, test error 44.50
# Epoch    27, train loss 0.695299, train error 23.43,  test loss 1.209799, test error 44.20
# Epoch    28, train loss 0.686803, train error 23.60,  test loss 1.201954, test error 44.10
# Epoch    29, train loss 0.686655, train error 23.43,  test loss 1.191586, test error 44.10
# Epoch    30, train loss 0.675282, train error 22.45,  test loss 1.207873, test error 44.00
# Epoch    31, train loss 0.676119, train error 23.50,  test loss 1.177208, test error 44.50
# Epoch    32, train loss 0.668457, train error 23.68,  test loss 1.173303, test error 43.60
# Epoch    33, train loss 0.667235, train error 22.40,  test loss 1.171835, test error 42.10
# Epoch    34, train loss 0.662947, train error 22.47,  test loss 1.211916, test error 43.50
# Epoch    35, train loss 0.652030, train error 22.78,  test loss 1.141370, test error 40.80
# Epoch    36, train loss 0.646298, train error 22.35,  test loss 1.196507, test error 45.60
# Epoch    37, train loss 0.647275, train error 22.03,  test loss 1.184896, test error 42.90
# Epoch    38, train loss 0.639838, train error 21.95,  test loss 1.183728, test error 43.90
# Epoch    39, train loss 0.638562, train error 22.40,  test loss 1.199441, test error 43.80
# Epoch    40, train loss 0.637876, train error 21.47,  test loss 1.164179, test error 42.10
# Epoch    41, train loss 0.624263, train error 21.03,  test loss 1.155108, test error 42.90
# Epoch    42, train loss 0.630572, train error 21.28,  test loss 1.176235, test error 43.60
# Epoch    43, train loss 0.625011, train error 21.72,  test loss 1.211091, test error 44.30
# Epoch    44, train loss 0.619003, train error 20.90,  test loss 1.165826, test error 42.80
# Epoch    45, train loss 0.625967, train error 21.55,  test loss 1.196937, test error 43.20
# Epoch    46, train loss 0.617469, train error 20.70,  test loss 1.177878, test error 43.40
# Epoch    47, train loss 0.616843, train error 20.75,  test loss 1.208339, test error 45.20
# Epoch    48, train loss 0.621923, train error 20.60,  test loss 1.178553, test error 42.90
# Epoch    49, train loss 0.616978, train error 20.95,  test loss 1.173683, test error 42.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
