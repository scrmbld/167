# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(D_k, D_o)
  );


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
  print("Initializing layer")

model.apply(weights_init)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Dropout(p=0.2, inplace=False)
#   (7): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001,betas=(.09, 0.999),)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.958972, train error 73.78,  test loss 2.069929, test error 78.20
# Epoch     1, train loss 1.739812, train error 66.90,  test loss 1.829315, test error 72.30
# Epoch     2, train loss 1.614190, train error 60.75,  test loss 1.741866, test error 70.10
# Epoch     3, train loss 1.513867, train error 57.55,  test loss 1.683404, test error 66.80
# Epoch     4, train loss 1.417050, train error 52.90,  test loss 1.605706, test error 62.90
# Epoch     5, train loss 1.338101, train error 48.97,  test loss 1.548396, test error 60.60
# Epoch     6, train loss 1.255605, train error 46.95,  test loss 1.520109, test error 59.50
# Epoch     7, train loss 1.160281, train error 41.47,  test loss 1.450204, test error 55.10
# Epoch     8, train loss 1.114414, train error 40.25,  test loss 1.407771, test error 54.30
# Epoch     9, train loss 1.065406, train error 38.97,  test loss 1.351484, test error 51.10
# Epoch    10, train loss 1.008512, train error 36.70,  test loss 1.353720, test error 53.20
# Epoch    11, train loss 0.990637, train error 34.72,  test loss 1.334702, test error 51.20
# Epoch    12, train loss 0.960553, train error 33.80,  test loss 1.331885, test error 52.80
# Epoch    13, train loss 0.921008, train error 32.20,  test loss 1.314018, test error 51.50
# Epoch    14, train loss 0.904523, train error 32.45,  test loss 1.324011, test error 50.80
# Epoch    15, train loss 0.882649, train error 31.32,  test loss 1.287719, test error 51.20
# Epoch    16, train loss 0.856074, train error 30.35,  test loss 1.294919, test error 48.90
# Epoch    17, train loss 0.835379, train error 29.12,  test loss 1.296381, test error 50.50
# Epoch    18, train loss 0.823024, train error 28.82,  test loss 1.255269, test error 47.80
# Epoch    19, train loss 0.801423, train error 28.70,  test loss 1.261845, test error 48.30
# Epoch    20, train loss 0.782311, train error 26.75,  test loss 1.250438, test error 48.20
# Epoch    21, train loss 0.763479, train error 26.05,  test loss 1.246716, test error 46.90
# Epoch    22, train loss 0.756326, train error 25.68,  test loss 1.241897, test error 48.10
# Epoch    23, train loss 0.741303, train error 25.50,  test loss 1.281020, test error 47.80
# Epoch    24, train loss 0.737862, train error 25.55,  test loss 1.251201, test error 49.30
# Epoch    25, train loss 0.723816, train error 24.30,  test loss 1.262441, test error 48.00
# Epoch    26, train loss 0.713607, train error 24.55,  test loss 1.232074, test error 48.10
# Epoch    27, train loss 0.710310, train error 23.65,  test loss 1.233746, test error 47.80
# Epoch    28, train loss 0.695037, train error 23.45,  test loss 1.242941, test error 47.70
# Epoch    29, train loss 0.687874, train error 23.65,  test loss 1.231245, test error 47.10
# Epoch    30, train loss 0.683131, train error 23.50,  test loss 1.213617, test error 46.60
# Epoch    31, train loss 0.671673, train error 22.45,  test loss 1.247714, test error 48.40
# Epoch    32, train loss 0.674006, train error 23.15,  test loss 1.234176, test error 45.10
# Epoch    33, train loss 0.669614, train error 22.38,  test loss 1.243824, test error 48.70
# Epoch    34, train loss 0.653830, train error 21.60,  test loss 1.233154, test error 47.90
# Epoch    35, train loss 0.657099, train error 22.40,  test loss 1.249622, test error 46.60
# Epoch    36, train loss 0.659412, train error 22.15,  test loss 1.211652, test error 46.60
# Epoch    37, train loss 0.645053, train error 22.10,  test loss 1.231536, test error 45.80
# Epoch    38, train loss 0.633730, train error 21.25,  test loss 1.242886, test error 48.50
# Epoch    39, train loss 0.645531, train error 22.32,  test loss 1.265620, test error 46.80
# Epoch    40, train loss 0.646071, train error 22.07,  test loss 1.270194, test error 46.00
# Epoch    41, train loss 0.640052, train error 21.55,  test loss 1.245843, test error 47.60
# Epoch    42, train loss 0.628511, train error 21.43,  test loss 1.236085, test error 46.40
# Epoch    43, train loss 0.636463, train error 20.95,  test loss 1.224436, test error 45.30
# Epoch    44, train loss 0.626973, train error 21.15,  test loss 1.242385, test error 48.30
# Epoch    45, train loss 0.632451, train error 21.85,  test loss 1.232930, test error 45.70
# Epoch    46, train loss 0.633673, train error 21.35,  test loss 1.226372, test error 47.30
# Epoch    47, train loss 0.612984, train error 20.97,  test loss 1.221550, test error 45.50
# Epoch    48, train loss 0.623364, train error 20.62,  test loss 1.238046, test error 46.20
# Epoch    49, train loss 0.616197, train error 21.15,  test loss 1.236285, test error 47.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
